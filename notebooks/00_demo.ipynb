# %% [markdown]
# # Notebook de démarrage — Deep Learning M2
#
# Vérification que l'environnement fonctionne.

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Python :", sys.version)
print("NumPy  :", np.__version__)
print("Pandas :", pd.__version__)

# %%
x = np.linspace(0, 2 * np.pi, 200)
plt.plot(x, np.sin(x))
plt.title("Test matplotlib")
plt.show()
